# %% [markdown]
# Init

# %%
from quick_fit import T_FLOOR_mesh_to_json
from depth_fit import depth_fit_nms_to_json
from json_to_stl import json_to_stl
from functions import meshify, simplify_mesh, meshfile


stl_path = "mesh/simplify_simplify_drogon_whole_without_base.stl"
out = "out/test"
stl = meshify(stl_path)
#stl = simplify_mesh(stl, 1000)
meshfile(stl, out + "_SIMPLIFIED.obj")
fbx = ["models/timber_structures/T_FLOOR.fbx","models/timber_structures/T_TRIFLOOR.fbx","models/timber_structures/T_WALLDIAGONAL.fbx"]

# %% [markdown]
# quick_fit Test

# %%
T_FLOOR_mesh_to_json(
    target_mesh=stl,
    out_path=out + "_T_FLOOR.json"
)
json_to_stl(out + "_T_FLOOR.json", "models", out +"_T_FLOOR.stl")
# Out:
# [stl_to_squares] input     : 2,994 triangles  ← <trimesh.Trimesh(vertices.shape=(1499, 3), faces.shape=(2994, 3))>
# [stl_to_squares] grid size : 5.37966
# [stl_to_squares] dist tol  : 0.538
# [stl_to_squares] patches   : 2,716
# [stl_to_squares] squares   : 871
# [stl_to_squares] done.
# [exporter] 872 total objects (incl. BASE_FLAG)
# [exporter] Written → out/test_T_FLOOR.json
# [json_to_stl] Reading test_T_FLOOR.json…
# [json_to_stl] 872 objects to process
# [mesh] Loaded T_FLOOR.fbx: 96 vertices, 44 faces
# [json_to_stl] Combining 871 meshes…
# [json_to_stl] Written → out/test_T_FLOOR.stl
# PosixPath('out/test_T_FLOOR.stl')

# %% [markdown]
# depth_fit Test

# %%
depth_fit_nms_to_json(
    target_mesh=stl,
    part_fbx_paths=fbx,
    out_path=out + "_depth.json",
)
# Out:
# [depth_fit] Loading mesh: <trimesh.Trimesh(vertices.shape=(1499, 3), faces.shape=(2994, 3))> …
# [depth_fit] 2994 faces, 1499 vertices
# [depth_fit] Loading part ^T_FLOOR …
# [depth_fit]   cross_area=282636.5016  cross_size=532.0312  part_max_dim=532.0312  axis=1
# [depth_fit] Loading part ^T_TRIFLOOR …
# [depth_fit]   cross_area=123302.0967  cross_size=530.7487  part_max_dim=530.7487  axis=1
# [depth_fit] Loading part ^T_WALLDIAGONAL …
# [depth_fit]   cross_area=107978.0016  cross_size=541.7614  part_max_dim=541.7614  axis=2
# [depth_fit] Face 1/2994 done, total placed so far: 1
# [depth_fit] Face 50/2994 done, total placed so far: 48
# [depth_fit] Face 100/2994 done, total placed so far: 98
# [depth_fit] Face 150/2994 done, total placed so far: 151
